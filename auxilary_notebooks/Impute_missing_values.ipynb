# %% [markdown]
# # Impute missing values

# %% [markdown]
# This notebook analyzes the `swiss_food_composition_database_proc` to see for outlier. The per category mean imputation is defined and tested.

# %% [markdown]
# ## Load and preprocess the data

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../data/swiss_food_composition_database_proc.csv')

# %%
dataset.shape
# Out:
# (1092, 43)

# %%
dataset.head()
# Out:
#    ID                         name  \
# 0   0                    Agar Agar
# 1   1                  Agave syrup
# 2   2                       Almond
# 3   3  Almond, dry roasted, salted
# 4   4      Almond, roasted, salted
#
#                                         category  energy_kcal  fat_g  \
# 0             Various/Gelling and binding agents        160.0    0.2
# 1                    Sweets/Sugar and sweeteners        293.0    0.0
# 2               Nuts, seeds and oleaginous fruit        624.0   52.1
# 3  Savoury snacks/Salted nuts, seeds and kernels        637.0   52.5
# 4  Savoury snacks/Salted nuts, seeds and kernels        649.0   55.2
#
#    fatty_acids_sat_g  fatty_acids_monounsat_g  fatty_acids_polyunsat_g  \
# 0                NaN                      NaN                      NaN
# 1                0.0                      NaN                      NaN
# 2                4.1                     31.4                     11.4
# 3                4.1                     33.1                     13.0
# 4                4.2                     34.8                     13.5
#
#    cholesterol_mg  carbohydrates_g  sugars_g  starch_g  fibres_g  protein_g  \
# 0             NaN              0.0       NaN       NaN      74.1        2.4
# 1             NaN             73.1       NaN       NaN       0.0        0.2
# 2             0.0              7.8       6.6       0.6      10.6       25.6
# 3             0.0             10.1       4.9       0.7      10.9       25.4
# 4             0.0              7.2       4.6       0.6      10.5       25.6
#
#    salt_g  alcohol_g  water_g  vit_A_activity_re_µg  vit_A_activity_rae_µg  \
# 0     0.3        NaN     20.5                   NaN                    NaN
# 1     0.0        NaN      NaN                   NaN                    NaN
# 2     0.0        0.0      3.3                   0.0                    0.0
# 3     0.6        0.0      2.4                   0.0                    0.0
# 4     0.8        0.0      2.8                   0.0                    0.0
#
#    retinol_µg  beta_carotene_activity_µg  beta_carotene_µg  vit_B1_mg  \
# 0         NaN                        NaN               NaN        NaN
# 1         NaN                        NaN               NaN        NaN
# 2         0.0                        0.0               0.0       0.15
# 3         0.0                        1.0               1.0       0.08
# 4         0.0                        1.0               1.0       0.09
#
#    vit_B2_mg  vit_B6_mg  vit_B12_µg  niacin_mg  folate_µg  \
# 0        NaN        NaN         NaN        NaN        NaN
# 1        NaN        NaN         NaN        NaN        NaN
# 2       0.94       0.13         0.0       1.88       55.9
# 3       1.20       0.14         0.0       3.64       55.0
# 4       0.78       0.12         0.0       3.67       27.0
#
#    panthotenic_acid_mg  vit_c_mg  vit_d_µg  vit_e_activity_mg  potassium_mg  \
# 0                  NaN       NaN       NaN                NaN          52.0
# 1                  NaN       NaN       NaN                NaN           NaN
# 2                 0.48       0.5       0.0              27.10         740.0
# 3                 0.32       0.0       0.0              23.90         710.0
# 4                 0.23       0.0       0.0              25.97         670.0
#
#    sodium_mg  chloride_mg  calcium_mg  magnesium_mg  phosphorus_mg  iron_mg  \
# 0      130.0          NaN       660.0         100.0           34.0      4.5
# 1        4.0          NaN         NaN           NaN            NaN      NaN
# 2        1.1         40.0       270.0         240.0          510.0      3.3
# 3      230.0       1190.0       270.0         280.0          470.0      3.7
# 4      330.0       1190.0       240.0         270.0          470.0      3.3
#
#    iodide_µg  zinc_mg  selenium_µg category_new
# 0        NaN      1.5          NaN        other
# 1        NaN      NaN          NaN       sweets
# 2        0.2      3.3          2.2       fruits
# 3        2.4      3.3          2.0         nuts
# 4        2.4      3.1          2.0         nuts

# %% [markdown]
# Remove columns and samples with more than 20% of values missing.

# %% [markdown]
# ### Remove columns with more than 20% missing values

# %%
percentage_present = 0.8
feature_threshold = math.ceil(percentage_present*dataset.shape[0]) # 20% of values missing
feature_threshold
# Out:
# 874

# %%
columns_before = dataset.columns
dataset = dataset.dropna(axis=1, thresh=feature_threshold)
columns_after = dataset.columns
columns_after
# Out:
# Index(['ID', 'name', 'category', 'energy_kcal', 'fat_g', 'fatty_acids_sat_g',
#        'fatty_acids_monounsat_g', 'fatty_acids_polyunsat_g', 'cholesterol_mg',
#        'carbohydrates_g', 'sugars_g', 'starch_g', 'fibres_g', 'protein_g',
#        'salt_g', 'alcohol_g', 'water_g', 'vit_A_activity_re_µg',
#        'vit_A_activity_rae_µg', 'retinol_µg', 'beta_carotene_activity_µg',
#        'beta_carotene_µg', 'vit_B1_mg', 'vit_B2_mg', 'vit_B6_mg', 'vit_B12_µg',
#        'niacin_mg', 'folate_µg', 'panthotenic_acid_mg', 'vit_c_mg', 'vit_d_µg',
#        'vit_e_activity_mg', 'potassium_mg', 'sodium_mg', 'chloride_mg',
#        'calcium_mg', 'magnesium_mg', 'phosphorus_mg', 'iron_mg', 'iodide_µg',
#        'zinc_mg', 'category_new'],
#       dtype='object')

# %% [markdown]
# ### Remove rows with more than 20% of values missing

# %%
row_threshold = math.ceil(percentage_present*dataset.shape[1]) # 20% of values missing
row_threshold
# Out:
# 34

# %%
rows_before = dataset.index
dataset = dataset.dropna(axis=0, thresh=row_threshold)
rows_after = dataset.index
dataset.shape
# Out:
# (1084, 42)

# %% [markdown]
# ## Impute missing values

# %%
# create a boolean mask for NaN values
nan_mask = dataset.isna().any(axis=1)

# create a new DataFrame with samples containing NaN values
df_with_nan_only = dataset[nan_mask]

# %%
df_with_nan_only.shape
# Out:
# (95, 42)

# %%
#dataset = dataset.dropna(axis=0) - disable the drop of the nans
dataset.shape
# Out:
# (1084, 42)

# %%
dataset['category_new'].unique() # find the unique categories
# Out:
# array(['fruits', 'nuts', 'cereals', 'sweets', 'other', 'dairy',
#        'non_alcoholic_beverages', 'vegetables', 'meat', 'herbs', 'sauce',
#        'alcoholic_beverages'], dtype=object)

# %%
dataset['category_new'].value_counts()
# Out:
# other                      228
# meat                       187
# cereals                    146
# vegetables                 127
# sweets                     118
# dairy                      103
# fruits                      99
# non_alcoholic_beverages     28
# alcoholic_beverages         22
# sauce                       16
# herbs                        7
# nuts                         3
# Name: category_new, dtype: int64

# %%
dataset.head()
# Out:
#    ID                                               name  \
# 2   2                                             Almond
# 3   3                        Almond, dry roasted, salted
# 4   4                            Almond, roasted, salted
# 5   5  Amaranth, seed, cooked (without addition of fa...
# 6   6                                Amaranth, seed, raw
#
#                                             category  energy_kcal  fat_g  \
# 2                   Nuts, seeds and oleaginous fruit        624.0   52.1
# 3      Savoury snacks/Salted nuts, seeds and kernels        637.0   52.5
# 4      Savoury snacks/Salted nuts, seeds and kernels        649.0   55.2
# 5  Cereal products, pulses and potatoes/Other cer...        119.0    2.1
# 6  Cereal products, pulses and potatoes/Other cer...        376.0    7.0
#
#    fatty_acids_sat_g  fatty_acids_monounsat_g  fatty_acids_polyunsat_g  \
# 2                4.1                     31.4                     11.4
# 3                4.1                     33.1                     13.0
# 4                4.2                     34.8                     13.5
# 5                0.4                      0.5                      0.8
# 6                1.5                      1.7                      2.8
#
#    cholesterol_mg  carbohydrates_g  sugars_g  starch_g  fibres_g  protein_g  \
# 2             0.0              7.8       6.6       0.6      10.6       25.6
# 3             0.0             10.1       4.9       0.7      10.9       25.4
# 4             0.0              7.2       4.6       0.6      10.5       25.6
# 5             0.0             18.1       0.5      17.6       3.5        5.0
# 6             0.0             56.8       1.7      55.1      11.0       15.8
#
#    salt_g  alcohol_g  water_g  vit_A_activity_re_µg  vit_A_activity_rae_µg  \
# 2     0.0        0.0      3.3                   0.0                    0.0
# 3     0.6        0.0      2.4                   0.0                    0.0
# 4     0.8        0.0      2.8                   0.0                    0.0
# 5     0.0        0.0     71.2                   0.0                    0.0
# 6     0.0        0.0     11.1                   0.0                    0.0
#
#    retinol_µg  beta_carotene_activity_µg  beta_carotene_µg  vit_B1_mg  \
# 2         0.0                        0.0               0.0       0.15
# 3         0.0                        1.0               1.0       0.08
# 4         0.0                        1.0               1.0       0.09
# 5         0.0                        0.0               0.0       0.02
# 6         0.0                        0.0               0.0       0.08
#
#    vit_B2_mg  vit_B6_mg  vit_B12_µg  niacin_mg  folate_µg  \
# 2       0.94       0.13         0.0       1.88       55.9
# 3       1.20       0.14         0.0       3.64       55.0
# 4       0.78       0.12         0.0       3.67       27.0
# 5       0.06       0.11         0.0       0.34       16.2
# 6       0.19       0.53         0.0       1.20       64.3
#
#    panthotenic_acid_mg  vit_c_mg  vit_d_µg  vit_e_activity_mg  potassium_mg  \
# 2                 0.48       0.5       0.0              27.10         740.0
# 3                 0.32       0.0       0.0              23.90         710.0
# 4                 0.23       0.0       0.0              25.97         670.0
# 5                 0.27       1.0       0.0               0.40         150.0
# 6                 0.95       4.2       0.0               1.19         480.0
#
#    sodium_mg  chloride_mg  calcium_mg  magnesium_mg  phosphorus_mg  iron_mg  \
# 2        1.1         40.0       270.0         240.0          510.0      3.3
# 3      230.0       1190.0       270.0         280.0          470.0      3.7
# 4      330.0       1190.0       240.0         270.0          470.0      3.3
# 5        1.9         36.0        58.0          84.0          180.0      3.0
# 6        4.0        110.0       160.0         250.0          560.0      9.0
#
#    iodide_µg  zinc_mg category_new
# 2        0.2      3.3       fruits
# 3        2.4      3.3         nuts
# 4        2.4      3.1         nuts
# 5        0.8      1.2      cereals
# 6        2.5      3.7      cereals

# %%
df_with_nan_only.head()
# Out:
#     ID                                               name  \
# 17  17                      Applesauce, sweetened, canned
# 18  18                    Applesauce, unsweetened, canned
# 46  46                   Beef ragout with sauce, prepared
# 47  47  Beef, boiling meat lean, cooked (without addit...
# 48  48  Beef, boiling meat with fat, cooked (without a...
#
#                                 category  energy_kcal  fat_g  \
# 17       Fruit/Cooked fruit (incl. cans)         89.0    0.3
# 18       Fruit/Cooked fruit (incl. cans)         55.0    0.3
# 46  Prepared dishes/Other savoury dishes         85.0    2.8
# 47                   Meat and offal/Beef        190.0    7.1
# 48                   Meat and offal/Beef        276.0   18.9
#
#     fatty_acids_sat_g  fatty_acids_monounsat_g  fatty_acids_polyunsat_g  \
# 17                0.1                      0.0                      0.1
# 18                0.1                      0.0                      0.1
# 46                0.4                      1.9                      0.4
# 47                3.3                      2.8                      0.6
# 48                7.9                      8.7                      1.2
#
#     cholesterol_mg  carbohydrates_g  sugars_g  starch_g  fibres_g  protein_g  \
# 17             0.0             20.5      20.4       0.1       1.9        0.3
# 18             0.0             11.7      11.6       0.1       2.1        0.3
# 46            31.0              3.0       1.5       NaN       0.6       11.6
# 47            98.0              0.0       0.0       NaN       0.0       31.7
# 48            80.0              0.0       0.0       NaN       0.0       26.6
#
#     salt_g  alcohol_g  water_g  vit_A_activity_re_µg  vit_A_activity_rae_µg  \
# 17     0.0        0.0     76.5                   NaN                    NaN
# 18     0.0        0.0     85.0                   NaN                    NaN
# 46     0.8        0.0     82.1                 123.0                   63.0
# 47     0.1        0.0     61.2                   9.0                    7.0
# 48     0.1        0.0     54.5                   8.0                    7.0
#
#     retinol_µg  beta_carotene_activity_µg  beta_carotene_µg  vit_B1_mg  \
# 17         NaN                        NaN               NaN       0.02
# 18         NaN                        NaN               NaN       0.02
# 46         2.0                      727.0             727.0       0.01
# 47         6.0                       13.0              13.0       0.02
# 48         6.0                       11.0              11.0       0.02
#
#     vit_B2_mg  vit_B6_mg  vit_B12_µg  niacin_mg  folate_µg  \
# 17       0.02       0.04        0.00       0.08        5.9
# 18       0.02       0.05        0.00       0.09        6.5
# 46       0.07       0.13        0.48        NaN        5.0
# 47       0.15       0.39        1.40        NaN        6.5
# 48       0.16       0.32        1.27       5.30        5.9
#
#     panthotenic_acid_mg  vit_c_mg  vit_d_µg  vit_e_activity_mg  potassium_mg  \
# 17                 0.08       2.3       0.0               0.34          97.0
# 18                 0.09       2.5       0.0               0.43         110.0
# 46                 0.35       0.9       0.2               0.70         130.0
# 47                 0.62       0.0       0.6               0.33         280.0
# 48                 0.67       0.0       0.5               0.30         230.0
#
#     sodium_mg  chloride_mg  calcium_mg  magnesium_mg  phosphorus_mg  iron_mg  \
# 17        3.6          2.1         4.4           3.6            8.1      0.2
# 18        4.0          2.2         4.8           4.0            9.0      0.2
# 46      300.0        470.0         9.9           8.9           91.0      0.8
# 47       48.0         90.0         5.9          19.0          200.0      2.8
# 48       41.0         82.0         5.0          16.0          160.0      1.8
#
#     iodide_µg  zinc_mg category_new
# 17        0.7      0.1       fruits
# 18        0.8      0.1       fruits
# 46        2.2      2.2        other
# 47        5.0      7.6         meat
# 48        4.5      5.3         meat

# %% [markdown]
# ## Impute missing values

# %%
def impute_missing_values(dataset:pd.DataFrame, category_col:str, feature_col_names:list)->pd.DataFrame:
    modified_dataset = dataset.copy()
    for feature in feature_col_names:
            modified_dataset[feature] = modified_dataset.groupby(category_col)[feature].transform(lambda x: x.fillna(x.mean()))
    return modified_dataset

# %%
cols = dataset.columns[3:-1]
# Out:
# 38

# %%
dataset_2 = impute_missing_values(dataset, category_col='category_new', feature_col_names=cols)

# %%
# Create a boolean mask for NaN values
nan_mask_2 = dataset_2.isna().any(axis=1)

# Create a new DataFrame with samples containing NaN values
df_with_nan_only_2 = dataset_2[nan_mask_2]
df_with_nan_only_2.shape
# Out:
# (0, 42)

# %% [markdown]
# There are no misisng values afterwards.
